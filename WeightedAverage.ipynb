# %%
with open("/net/jam-amaro-shared/bccgc4/xtaldocking/Gromos_docking/Docking_Results/score.txt","r") as input_file:
    content = input_file.readlines()
content = [float(x.strip().split()[2]) for x in content] 

# seperates file into 10 different lists
L1 = content[0:459]
L2 = content[459:459*2]
L3 = content[459*2:459*3]
L4 = content[459*3:459*4]
L5 = content[459*4:459*5]
L6 = content[459*5:459*6]
L7 = content[459*6:459*7]
L8 = content[459*7:459*8]
L9 = content[459*8:459*9]
L10 = content[459*9:459*10]
avgscore = []

#calculates the weighted average for each ligand
for i in range(len(L1)):
    average = L1[i]*(2988.0/4500) + L2[i]* (363.0/4500) + L3[i]* (287.0/4500) + L4[i]*(173.0/4500) + L5[i]*(113.0/4500)  + L6[i]*(58.0/4500) + L7[i]*(54.0/4500) + L8[i]*(41.0/4500) + L9[i]*(41.0/4500) +  L10[i]*(31.0/4500)
    avgscore.append(average)
print(avgscore)
# Out:
# [-1.7527755008273656, -2.621060064792633, -2.903169936286079, -2.7625423373116385, -3.43102643081877, -3.293563133027819, -2.2303987666765854, -3.477806077056461, -2.7128714825842124, -4.21124953979916, -2.7685813718371923, -2.787550797515445, -3.079272466818492, -1.9009415062401027, -2.405063033633762, -3.2874250322447884, -3.3105692174699577, -3.823560335689121, -3.5733623345692958, -3.26381678946813, -3.080246545155843, -2.8393602957195703, -4.251407532638974, -2.4279872845543746, -0.41121054501003684, -3.3963699983490843, -2.986460692087809, -2.9750726567374333, -2.1061553199026317, -3.67053931511773, -2.8647479853100246, -2.7057212083074784, -3.2671843118667603, -3.3038482543097607, -3.8696924699147544, -4.160802876419491, -4.494167515436809, -4.1133010880152385, -3.817870070987278, -3.779880089759826, -3.867948456552293, -4.302358544455634, -4.700025498814054, -3.130376551628113, -2.2065219197803074, -3.610994356632233, -2.9590660552978516, -0.6802261278529962, -3.3511671853595
# ...
